# %%
import matplotlib.pyplot as plt

# %%
with open('insertion.txt', 'r') as f:
    lines = f.readlines()

    xAxis = [i for i in range(len(lines))]
    yAxis = [(int)(line.split()[1]) for line in lines]

# %%
plt.plot(xAxis, yAxis)
plt.show()
