# %%
import matplotlib.pyplot as plt

# %%
with open('insCmp.txt', 'r') as f:
    lines = f.readlines()

    insCmpRandX = [i for i in range(len(lines))]
    insCmpRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('binCmp.txt', 'r') as f:
    lines = f.readlines()

    binCmpRandX = [i for i in range(len(lines))]
    binCmpRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('sortMergeCmp.txt', 'r') as f:
    lines = f.readlines()

    sortCmpRandX = [i for i in range(len(lines))]
    sortCmpRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('delCmp.txt', 'r') as f:
    lines = f.readlines()

    delCmpRandX = [i for i in range(len(lines))]
    delCmpRandY = [(int)(line.split()[1]) for line in lines]

# %% [markdown]
# # Quadratic

# %%
with open('bubble.txt', 'r') as f:
    lines = f.readlines()

    bubRandX = [i for i in range(len(lines))]
    bubRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('insertion.txt', 'r') as f:
    lines = f.readlines()

    insRandX = [i for i in range(len(lines))]
    insRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('insertionBin.txt', 'r') as f:
    lines = f.readlines()

    binRandX = [i for i in range(len(lines))]
    binRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('insertionDel.txt', 'r') as f:
    lines = f.readlines()

    delRandX = [i for i in range(len(lines))]
    delRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('selection.txt', 'r') as f:
    lines = f.readlines()

    selRandX = [i for i in range(len(lines))]
    selRandY = [(int)(line.split()[1]) for line in lines]

# %% [markdown]
# # Fast sortings

# %%
with open('sortRand.txt', 'r') as f:
    lines = f.readlines()

    qRandX = [i for i in range(len(lines))]
    qRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('sortMedMed.txt', 'r') as f:
    lines = f.readlines()

    medRandX = [i for i in range(len(lines))]
    medRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('sortMed3.txt', 'r') as f:
    lines = f.readlines()

    med3RandX = [i for i in range(len(lines))]
    med3RandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('sortLsd.txt', 'r') as f:
    lines = f.readlines()

    lsdRandX = [i for i in range(len(lines))]
    lsdRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('sortCent.txt', 'r') as f:
    lines = f.readlines()

    centRandX = [i for i in range(len(lines))]
    centRandY = [(int)(line.split()[1]) for line in lines]

# %%
with open('sortMerge.txt', 'r') as f:
    lines = f.readlines()

    mergeRandX = [i for i in range(len(lines))]
    mergeRandY = [(int)(line.split()[1]) for line in lines]

# %% [markdown]
# # Building graphics

# %%
plt.xlabel('Element count (1000 - 10^5)', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Quadratic sortings comparison ', fontsize = 15)

plt.plot(bubRandX, bubRandY)
plt.plot(selRandX, selRandY)
plt.plot(insRandX, insRandY)
plt.plot(delRandX, delRandY)
plt.plot(binRandX, binRandY)

plt.legend(['Bubble', 'Selection', 
            'Insertion', 'Insertion (2)', 'Insertion with bin search'])

plt.xticks([])  # removing numbers on x
plt.show()

# %%
plt.xlabel('Element count (1000 - 10^7)', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Qsort with different pivots', fontsize = 15)

plt.plot(qRandX, qRandY)
plt.plot(medRandX, medRandY)
plt.plot(med3RandX, med3RandY)
plt.plot(centRandX, centRandY)

plt.legend(['Random', 'Median of medians', 
            'Median of 3', 'Center'])

plt.xticks([])  # removing numbers on x
plt.show()

# %%
plt.xlabel('Element count (1000 - 10^7)', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('"Fast" sortings comparison', fontsize = 15)

plt.plot(qRandX, qRandY)
plt.plot(med3RandX, med3RandY)
plt.plot(centRandX, centRandY)
plt.plot(mergeRandX, mergeRandY)
plt.plot(lsdRandX, lsdRandY)

plt.legend(['QSort with random pivot',
            'QSort with median of 3 pivot', 'QSort with center pivot',
            'Merge sort', 'LSD'])

plt.xticks([])  # removing numbers on x
plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ns)', color = 'gray')

plt.title('Insertion vs merge comparison', fontsize = 15)

plt.plot(insCmpRandX, insCmpRandY)
plt.plot(delCmpRandX, delCmpRandY)
plt.plot(binCmpRandX, binCmpRandY)
plt.plot(sortCmpRandX, sortCmpRandY)

plt.legend(['Insertion classic', 'Insertion (2)', 
            'Insertion with bin search', 'Classic merge'])

# plt.xticks([])  # removing numbers on x
plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('All sortings comparison ', fontsize = 15)

plt.plot(bubRandX, bubRandY)
plt.plot(selRandX, selRandY)
plt.plot(insRandX, insRandY)
plt.plot(delRandX, delRandY)
plt.plot(binRandX, binRandY)
plt.plot(qRandX, qRandY)
plt.plot(med3RandX, med3RandY)
plt.plot(centRandX, centRandY)
plt.plot(mergeRandX, mergeRandY)
plt.plot(lsdRandX, lsdRandY)

plt.legend(['Bubble', 'Selection', 
            'Insertion', 'Insertion (2)', 'Insertion with bin search', 'QSort with random pivot',
            'QSort with median of 3 pivot', 'QSort with center pivot',
            'Merge sort', 'LSD'])

plt.xticks([])  # removing numbers on x
plt.show()
